# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()
client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="海為什麼是藍的?"
)

print(interaction.output_text)
# Out:
# 海之所以呈現藍色，主要原因並不是像鏡子一樣「反射了天空的顏色」，而是因為**陽光與海水分子之間的物理交互作用（吸收與散射）**。
#
# 這可以拆解為以下幾個關鍵原因：
#
# ### 1. 太陽光是由「彩虹七色」組成的
# 我們平常看到的陽光好像是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等不同顏色的光混合而成的。這些光以波的形式傳播：
# *   **紅光、橙光**：波長較長，能量較低。
# *   **藍光、紫光**：波長較短，能量較高。
#
# ### 2. 海水會「吸收」紅光
# 當陽光射入海水中時，水分子會開始吸收光線。
# *   海水分子非常喜歡吸收**波長較長的紅光、橙光和黃光**。在陽光照射到海水表面後不久（大約在水深15米以內），紅光就幾乎被水分子完全吸收並轉化為熱能了。
# *   相反地，**波長較短的藍光**不容易被海水分子吸收，能夠穿透到更深的水域。
#
# ### 3. 藍光的「散射」效果
# 沒有被吸收的藍光在海水中傳播時，會碰撞到水分子，並向四面八方「散射」（Scattering）開來。當這些被散射的藍光有一部分折射回我們的眼睛時，我們看到的海水就是藍色的了。
#
# ### 為什麼不是「紫色」？
# 你可能會問，紫光的波長比藍光更短，為什麼海不是紫色的？
# 兩個原因：
# 1.  **太陽光中藍光的比例本來就比紫光多**。
# 2.  **人類的眼睛對藍光更為敏感**，所以我們的大腦接收到的信號是藍色。
#
# ---
#
# ### 補充：為什麼有些海看起來是綠色、黃色或黑色？
# 並非所有的海都是藍色的，這取決於海水裡有什麼：
# *   **綠色的海**：如果海水裡有大量的**浮游植物（藻類）**，它們體內的葉綠素會吸收藍光和紅光，反射出綠光，海水就會呈現綠色。這通常代表水質很營養。
# *   **黃褐色、混濁的海**：如果靠近河口，海水裡含有大量的泥沙、有機物或沉積物，就會呈現黃褐色。
# *   **深藍色甚至黑色**：當水深超過200米後，幾乎所有的光線都被吸收了，深海就會變成一片漆黑。
