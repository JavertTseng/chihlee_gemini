# %%
print("hello 0816")
# Out:
# hello 0816

# %%
print("這是整數", 50)
print("這是浮點數", 50.5)
print("這是字串", 'robert111')
print("這是布林值", True)
print("這是布林值", False)
# Out:
# 這是整數 50
# 這是浮點數 50.5
# 這是字串 robert111
# 這是布林值 True
# 這是布林值 False
