# %%
print("hello 0816")
# Out:
# hello 0816

# %%
print("這是整數", 50)
print("這是浮點數", 50.5)
print("這是字串", 'robert111')
print("這是布林值", True)
print("這是布林值", False)
# Out:
# 這是整數 50
# 這是浮點數 50.5
# 這是字串 robert111
# 這是布林值 True
# 這是布林值 False

# %%
print(3 + 5)
print(3 + 5 + 10)
print( 3 + 5 * 2)
print((3 + 5) * 2)
print(99 ** 99)
# Out:
# 8
# 18
# 13
# 16
# 369729637649726772657187905628805440595668764281741102430259972423552570455277523421410650010128232727940978889548326540119429996769494359451621570193644014418071060667659301384999779999159200499899

# %%
print(int("5") + 5)
# Out:
# 10

# %%
n = int(input("請輸入整數:"))
m = float(input("請輸入另一個數值"))
print(n, "*", m, "=",  n * m)
# Out:
# 請輸入整數: 53
# 請輸入另一個數值 43.9
# 53 * 43.9 = 2326.7

# %%
import math

radius = float(input("請輸入半徑:"))
area = radius ** 2 * math.pi
print("半徑:", radius, ", 圓面積=", area)
# Out:
# 請輸入半徑: 10
# 半徑: 10.0 , 圓面積= 314.1592653589793
